# %% [markdown]
# ## Actividad 1. Exploración y preprocesamiento de datos
#
# En esta actividad se pide realizar una exploración y preprocesamiento de datos sobre un conjunto de datos de precios de gasolina. El objetivo es preparar los datos para su posterior análisis y modelado.
#
#  **Alumna: Anabel Díaz**

# %% [markdown]
# ### Paso 1: Cargar el conjunto de datos

# %%
import pandas as pd

df = pd.read_csv("gii32_ act1_precios_carburantes_24.csv")
df.head()
# Out:
#   Provincia  Municipio  Localidad  Código postal  \
# 0  ALBACETE  ABENGIBRE  ABENGIBRE           2250
# 1  ALBACETE   ALBACETE   ALBACETE           2001
# 2  ALBACETE   ALBACETE   ALBACETE           2001
# 3  ALBACETE   ALBACETE   ALBACETE           2001
# 4  ALBACETE   ALBACETE   ALBACETE           2001
#
#                                            Dirección Precio gasolina 95 E5  \
# 0                     AVENIDA CASTILLA LA MANCHA, 26                 1,529
# 1                     CALLE FEDERICO GARCIA LORCA, 5                   NaN
# 2                     CALLE FEDERICO GARCIA LORCA, 1                 1,409
# 3                            AVENIDA 1º DE MAYO, S/N                 1,539
# 4  CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA...                 1,549
#
#   Precio gasóleo A Tipo venta Tipo servicio     Rótulo
# 0            1,419          P             A  Nº 10.935
# 1            1,560          R             A      CEPSA
# ...

# %% [markdown]
# ### Paso 2: Explorar el conjunto de datos
# Conocer el número de filas y columnas del dataset para entender su estructura y dimensiones. Esto es fundamental para planificar el análisis y preprocesamiento de los datos.

# %%
df.shape
# Out:
# (11865, 10)

# %% [markdown]
# ### Paso 3: Identificar el tipo de datos de cada columna
# Conocer el dataset y evitar errores en el análisis posterior

# %%
df.columns
# Out:
# Index(['Provincia', 'Municipio', 'Localidad', 'Código postal', 'Dirección',
#        'Precio gasolina 95 E5', 'Precio gasóleo A', 'Tipo venta',
#        'Tipo servicio', 'Rótulo'],
#       dtype='object')
